# %% [markdown]
# # Comoparing 2 recordings
# Goals
# Whole recording comparisons
# * Graph recordings and compare bandranges visually (psd and topo)
# * See the difference between band ranges as a statistic
# * see the difference between band range ratios as a statistic (delta/apha ration theta/alpha ratio ect.)
# * make a correlation matrix between electrods and wavebands and waveband ratios
#
# Epoch Comparisons
# * reject epochs too flat / too high amplitude
# * Graph recordings and compare bandranges visually (psd and topo)
# * See the difference between band ranges as a statistic
# * see teh difference between band range ratios as a statistic
# * make a correlation matrix between electrods and wavebands and waveband ratios

# %% [markdown]
# # Whole recording comparisons

# %%
# load the recordings into pandas and clean up pandas

# %%
import pandas as pd
import mne

# %%
recordingBefore = "/Users/user/projects/museExperiments/exp1_09-14-2025_1800/EEG_recording_2025-09-14-22.33.39.csv"
recordingAfter = "/Users/user/projects/museExperiments/exp1_09-14-2025_1800/EEG_recording_2025-09-14-22.53.16.csv"

# %%
dataframeBefore = pd.read_csv(recordingBefore)
dataframeAfter = pd.read_csv(recordingAfter)

# %%
# dropping RightAux since it is only needed if adding costum channels and renameing the columns to match MNE
dataframeBefore = dataframeBefore.drop(["Right AUX","timestamps"], axis=1)
dataframeAfter = dataframeAfter.drop(["Right AUX", "timestamps"], axis=1)

# %%
# create the dataframe

# %%
ch_names = list(dataframeBefore.columns) # tp9 af7 af8 tp10
ch_types = ["eeg"]*len(ch_names) # 4 eeg channels
sampling_freq = 256 # muse 2 is at 256hz
info = mne.create_info(ch_names, ch_types=ch_types, sfreq=sampling_freq)
info.set_montage("standard_1020")
print(info)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: TP9, AF7, AF8, TP10
#  chs: 4 EEG
#  custom_ref_applied: False
#  dig: 7 items (3 Cardinal, 4 EEG)
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 4
#  projs: []
#  sfreq: 256.0 Hz
# >

# %%
# creating the MNE raw objects

# %%
rawBefore = mne.io.RawArray(dataframeBefore.values.T, info, verbose=True)  
rawAfter = mne.io.RawArray(dataframeAfter.values.T, info, verbose=True)
# Out:
# Creating RawArray with float64 data, n_channels=4, n_times=35964
#     Range : 0 ... 35963 =      0.000 ...   140.480 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4, n_times=44952
#     Range : 0 ... 44951 =      0.000 ...   175.590 secs
# Ready.

# %%
# Doing analysis on the raw MNE object 
l_freq = 1     # Lower cutoff (Muse is not good below 1 Hz)
h_freq = 50    # Upper cutoff (for clean gamma, avoids muscle/noise)
# note the total cuttoff is 128hz but after 50hz its mostly noise/muslce artifacts
rawBefore.filter(l_freq=l_freq, h_freq=h_freq)  # In-place bandpass filter
rawAfter.filter(l_freq=l_freq, h_freq=h_freq)  # In-place bandpass filter
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 845 samples (3.301 s)
# <RawArray | 4 x 44952 (175.6 s), ~1.4 MiB, data loaded>

# %% [markdown]
# # Graphing PSD and topomap

# %%
rawBefore.compute_psd(fmin=l_freq, fmax=h_freq+5).plot()
# Out:
# Effective window size : 8.000 (s)
# Plotting power spectral density (dB=True).
# /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
rawAfter.compute_psd(fmin=l_freq, fmax=h_freq+5).plot()
# Out:
# Effective window size : 8.000 (s)
# Plotting power spectral density (dB=True).
# /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
rawBefore.compute_psd(fmin=l_freq, fmax=h_freq+5).plot_topomap()
# Out:
# Effective window size : 8.000 (s)
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
rawAfter.compute_psd(fmin=l_freq, fmax=h_freq+5).plot_topomap()
# Out:
# Effective window size : 8.000 (s)

# %% [markdown]
# # Doing Epoch Analysis

# %%
import numpy as np

epoch_duration = 3  # seconds
sfreq = rawBefore.info['sfreq']
n_samples = int(epoch_duration * sfreq)

def make_epochs(
    raw,
    epoch_duration=3,
    max_ptp=None,     # Maximum allowed PTP amplitude in μV, e.g., 800
    min_ptp=None,     # Minimum allowed PTP amplitude in μV, e.g., 0.5
    event_id=1
):
    sfreq = raw.info['sfreq']
    n_samples = int(epoch_duration * sfreq)
    n_total_samples = raw.n_times

    # Calculate event onsets for non-overlapping epochs
    event_onsets = np.arange(0, n_total_samples - n_samples + 1, n_samples)
    events = np.column_stack((
        event_onsets,
        np.zeros_like(event_onsets),
        np.ones_like(event_onsets) * event_id
    ))

    # Set up rejection/flatness dicts for MNE, converting μV to V
    reject_dict = {'eeg': max_ptp * 1e-6} if max_ptp is not None else None
    flat_dict = {'eeg': min_ptp * 1e-6} if min_ptp is not None else None

    print(f"Making epochs: reject={reject_dict}, flat={flat_dict}")

    return mne.Epochs(
        raw,
        events,
        event_id=event_id,
        tmin=0,
        tmax=epoch_duration - 1/sfreq,
        baseline=None,
        preload=True,
        reject=reject_dict,
        flat=flat_dict
    )
epochsBefore = make_epochs(rawBefore)
epochsAfter = make_epochs(rawAfter)
# Out:
# Making epochs: reject=None, flat=None
# Not setting metadata
# 46 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 46 events and 768 original time points ...
# 0 bad epochs dropped
# Making epochs: reject=None, flat=None
# Not setting metadata
# 58 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 58 events and 768 original time points ...
# 0 bad epochs dropped

# %%
psdBefore = rawBefore.compute_psd(fmin=l_freq, fmax=h_freq+5)
psdAfter = rawAfter.compute_psd(fmin=l_freq, fmax=h_freq+5)
# Out:
# Effective window size : 8.000 (s)
# Effective window size : 8.000 (s)

# %%
psdBefore.plot()
# Out:
# Plotting power spectral density (dB=True).
# /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
psdAfter.plot()
# Out:
# Plotting power spectral density (dB=True).
# /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>

# %%
import matplotlib.pyplot as plt

mean_psd_before = psdBefore.get_data().mean(axis=0)  # average over channels
mean_psd_after = psdAfter.get_data().mean(axis=0)

plt.figure()
plt.plot(psdBefore.freqs, mean_psd_before, label='Before')
plt.plot(psdAfter.freqs, mean_psd_after, label='After')
plt.xlabel('Frequency (Hz)')
plt.ylabel('PSD (uV^2/Hz)')
plt.legend()
plt.show()
# Out:
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNELineFigure size 1000x350 with 2 Axes>

# %% [markdown]
# # Using MNE - features to get the features and do a deeper analysis

# %%
# making data using MNE-featurs

# %%
# !pip uninstall mne-features mne scikit-learn -y
# Out:
# Found existing installation: mne-features 0.3
# Uninstalling mne-features-0.3:
#   Successfully uninstalled mne-features-0.3
# Found existing installation: mne 1.10.1
# Uninstalling mne-1.10.1:
#   Successfully uninstalled mne-1.10.1
# Found existing installation: scikit-learn 1.7.2
# Uninstalling scikit-learn-1.7.2:
#   Successfully uninstalled scikit-learn-1.7.2

# %%
pip install --upgrade --force-reinstall mne-features mne scikit-learn
# Out:
# Collecting mne-features
#   Using cached mne_features-0.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting mne
#   Using cached mne-1.10.1-py3-none-any.whl.metadata (20 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting numpy (from mne-features)
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting scipy (from mne-features)
#   Using cached scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting numba (from mne-features)
#   Using cached numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from mne-features)
#   Using cached pywavelets-1.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting pandas (from mne-features)
#   Using cached pandas-2.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting decorator (from mne)
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting jinja2 (from mne)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting lazy-loader>=0.3 (from mne)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting matplotlib>=3.7 (from mne)
#   Using cached matplotlib-3.10.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting packaging (from mne)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pooch>=1.5 (from mne)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting tqdm (from mne)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.7->mne)
#   Using cached contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.7->mne)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.7->mne)
#   Using cached fonttools-4.59.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.7->mne)
#   Using cached kiwisolver-1.4.9-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.7->mne)
#   Using cached pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.7->mne)
#   Downloading pyparsing-3.2.4-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.7->mne)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5.0 (from pooch>=1.5->mne)
#   Using cached platformdirs-4.4.0-py3-none-any.whl.metadata (12 kB)
# Collecting requests>=2.19.0 (from pooch>=1.5->mne)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.7->mne)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.5->mne)
#   Using cached charset_normalizer-3.4.3-cp310-cp310-macosx_10_9_universal2.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.5->mne)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.5->mne)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.5->mne)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->mne)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba->mne-features)
#   Using cached llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting pytz>=2020.1 (from pandas->mne-features)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->mne-features)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Using cached mne_features-0.3-py3-none-any.whl (26 kB)
# Using cached mne-1.10.1-py3-none-any.whl (7.4 MB)
# Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
# Using cached scikit_learn-1.7.2-cp310-cp310-macosx_12_0_arm64.whl (8.7 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached matplotlib-3.10.6-cp310-cp310-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.59.2-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.9-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pillow-11.3.0-cp310-cp310-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached platformdirs-4.4.0-py3-none-any.whl (18 kB)
# Downloading pyparsing-3.2.4-py3-none-any.whl (113 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp310-cp310-macosx_10_9_universal2.whl (207 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Using cached scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Using cached numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
# Using cached llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl (26.2 MB)
# Using cached pandas-2.3.2-cp310-cp310-macosx_11_0_arm64.whl (10.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached pywavelets-1.8.0-cp310-cp310-macosx_11_0_arm64.whl (4.3 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: pytz, urllib3, tzdata, tqdm, threadpoolctl, six, pyparsing, platformdirs, pillow, packaging, numpy, MarkupSafe, llvmlite, kiwisolver, joblib, idna, fonttools, decorator, cycler, charset_normalizer, certifi, scipy, requests, PyWavelets, python-dateutil, numba, lazy-loader, jinja2, contourpy, scikit-learn, pooch, pandas, matplotlib, mne, mne-features
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
#   Attempting uninstall: tzdata;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/35 [urllib3]
#     Found existing installation: tzdata 2025.237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/35 [urllib3]
#     Uninstalling tzdata-2025.2:7m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/35 [urllib3]
#       Successfully uninstalled tzdata-2025.2;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/35 [urllib3]
#   Attempting uninstall: tqdm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#     Found existing installation: tqdm 4.67.15;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#     Uninstalling tqdm-4.67.1:;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#       Successfully uninstalled tqdm-4.67.18;5;237m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#   Attempting uninstall: threadpoolctl0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#     Found existing installation: threadpoolctl 3.6.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#     Uninstalling threadpoolctl-3.6.0:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/35 [tzdata]
#       Successfully uninstalled threadpoolctl-3.6.00m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#   Attempting uninstall: six38;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#     Found existing installation: six 1.17.0╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#     Uninstalling six-1.17.0:8;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#       Successfully uninstalled six-1.17.04m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#   Attempting uninstall: pyparsing49;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#     Found existing installation: pyparsing 3.2.3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#     Uninstalling pyparsing-3.2.3:49;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#       Successfully uninstalled pyparsing-3.2.30m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/35 [threadpoolctl]
#   Attempting uninstall: platformdirs2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#     Found existing installation: platformdirs 4.4.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#     Uninstalling platformdirs-4.4.0:9;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#       Successfully uninstalled platformdirs-4.4.0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#   Attempting uninstall: pillow8;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#     Found existing installation: pillow 11.3.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#     Uninstalling pillow-11.3.0:;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#       Successfully uninstalled pillow-11.3.0m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/35 [pyparsing]
#   Attempting uninstall: packagingm╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/35 [pillow]rsing]
#     Found existing installation: packaging 25.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/35 [pillow]
#     Uninstalling packaging-25.0:38;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/35 [pillow]
#       Successfully uninstalled packaging-25.0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/35 [pillow]
#   Attempting uninstall: numpy━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/35 [packaging]
#     Found existing installation: numpy 2.2.6━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/35 [packaging]
#     Uninstalling numpy-2.2.6:0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/35 [packaging]
#       Successfully uninstalled numpy-2.2.6╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/35 [packaging]
#   Attempting uninstall: MarkupSafe0m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#     Found existing installation: MarkupSafe 3.0.2━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#     Uninstalling MarkupSafe-3.0.2:38;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#       Successfully uninstalled MarkupSafe-3.0.2m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#   Attempting uninstall: llvmlite╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#     Found existing installation: llvmlite 0.44.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#     Uninstalling llvmlite-0.44.0:╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#       Successfully uninstalled llvmlite-0.44.00m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/35 [numpy]
#   Attempting uninstall: kiwisolver╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#     Found existing installation: kiwisolver 1.4.914m╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#     Uninstalling kiwisolver-1.4.9:╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#       Successfully uninstalled kiwisolver-1.4.9;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#   Attempting uninstall: joblib╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#     Found existing installation: joblib 1.5.238;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#     Uninstalling joblib-1.5.2:╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#       Successfully uninstalled joblib-1.5.29;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/35 [llvmlite]
#   Attempting uninstall: idna━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 14/35 [joblib]lite]
#     Found existing installation: idna 3.105;237m╺━━━━━━━━━━━━━━━━━━━━━━━ 14/35 [joblib]
#     Uninstalling idna-3.10:━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 14/35 [joblib]
#       Successfully uninstalled idna-3.108;5;237m╺━━━━━━━━━━━━━━━━━━━━━━━ 14/35 [joblib]
#   Attempting uninstall: fonttools╺━━━━━━━━━━━━━━━━━━━━━━━ 14/35 [joblib]
#     Found existing installation: fonttools 4.59.2━━━━━━━━━━━━━━━━━━━━━━━ 14/35 [joblib]
#     Uninstalling fonttools-4.59.2:━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#       Successfully uninstalled fonttools-4.59.237m╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#   Attempting uninstall: decorator━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#     Found existing installation: decorator 5.2.17m╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#     Uninstalling decorator-5.2.1:━━╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#       Successfully uninstalled decorator-5.2.1237m╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#   Attempting uninstall: cycler━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#     Found existing installation: cycler 0.12.1237m╺━━━━━━━━━━━━━━━━━━━━━ 16/35 [fonttools]
#     Uninstalling cycler-0.12.1:━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#       Successfully uninstalled cycler-0.12.18;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#   Attempting uninstall: charset_normalizer╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#     Found existing installation: charset-normalizer 3.4.34m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#     Uninstalling charset-normalizer-3.4.3:╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#       Successfully uninstalled charset-normalizer-3.4.3114m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#   Attempting uninstall: certifi━━━━━━╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#     Found existing installation: certifi 2025.8.349;38;114m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#     Uninstalling certifi-2025.8.3:━━━╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#       Successfully uninstalled certifi-2025.8.3;249;38;114m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#   Attempting uninstall: scipy━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#     Found existing installation: scipy 1.15.3;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#     Uninstalling scipy-1.15.3:━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#       Successfully uninstalled scipy-1.15.338;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━ 18/35 [cycler]
#   Attempting uninstall: requests━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 21/35 [scipy]ler]
#     Found existing installation: requests 2.32.58;5;237m╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#     Uninstalling requests-2.32.5:━━━━━━━━╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#       Successfully uninstalled requests-2.32.5╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#   Attempting uninstall: PyWavelets━━━━━━━╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#     Found existing installation: PyWavelets 1.8.0;5;237m╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#     Uninstalling PyWavelets-1.8.0:━━━━━━━╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#       Successfully uninstalled PyWavelets-1.8.038;5;237m╺━━━━━━━━━━━━━━━ 21/35 [scipy]
#   Attempting uninstall: python-dateutil━━━━━━━━╺━━━━━━━━━━━━━ 23/35 [PyWavelets]
#     Found existing installation: python-dateutil 2.9.0.post0━━━━━━━━━━━━━ 23/35 [PyWavelets]
#     Uninstalling python-dateutil-2.9.0.post0:0m╺━━━━━━━━━━━━━ 23/35 [PyWavelets]
#       Successfully uninstalled python-dateutil-2.9.0.post0╺━━━━━━━━━━━━━ 23/35 [PyWavelets]
#   Attempting uninstall: numba━━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 23/35 [PyWavelets]
#     Found existing installation: numba 0.61.20m╺━━━━━━━━━━━━━ 23/35 [PyWavelets]
#     Uninstalling numba-0.61.2:━━━━━━━━━━━━━╺━━━━━━━━━━━━━ 23/35 [PyWavelets]
#       Successfully uninstalled numba-0.61.2━━━━━━╸━━━━━━━━━━━ 25/35 [numba]
#   Attempting uninstall: lazy-loader━━━━━━━━━━━━━━╸━━━━━━━━━━━ 25/35 [numba]
#     Found existing installation: lazy_loader 0.4m╸━━━━━━━━━━━ 25/35 [numba]
#     Uninstalling lazy_loader-0.4:━━━━━━━━━━━━╸━━━━━━━━━━━ 25/35 [numba]
#       Successfully uninstalled lazy_loader-0.4╸━━━━━━━━━━━ 25/35 [numba]
#   Attempting uninstall: jinja2━━━━━━━━━━━━━━━╸━━━━━━━━━━━ 25/35 [numba]
#     Found existing installation: Jinja2 3.1.6╸━━━━━━━━━━━ 25/35 [numba]
#     Uninstalling Jinja2-3.1.6:━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━ 27/35 [jinja2]
#       Successfully uninstalled Jinja2-3.1.6━━━━╸━━━━━━━━━ 27/35 [jinja2]
#   Attempting uninstall: contourpy━━━━━━━━━━━━━━╸━━━━━━━━━ 27/35 [jinja2]
#     Found existing installation: contourpy 1.3.2╸━━━━━━━━━ 27/35 [jinja2]
#     Uninstalling contourpy-1.3.2:━━━━━━━━━━━━━━╸━━━━━━━━━ 27/35 [jinja2]
#       Successfully uninstalled contourpy-1.3.2━╸━━━━━━━━━ 27/35 [jinja2]
#   Attempting uninstall: pooch━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 29/35 [scikit-learn]
#     Found existing installation: pooch 1.8.2━━━━━━╺━━━━━━ 29/35 [scikit-learn]
#     Uninstalling pooch-1.8.2:━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 30/35 [pooch]rn]
#       Successfully uninstalled pooch-1.8.2━━━━━━━━━╺━━━━━ 30/35 [pooch]
#   Attempting uninstall: pandas━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 30/35 [pooch]
#     Found existing installation: pandas 2.3.2━━━━━━╺━━━━━ 30/35 [pooch]
#     Uninstalling pandas-2.3.2:━━━━━━━━━━━━━━━━━━━━━╺━━━━━ 30/35 [pooch]
#       Successfully uninstalled pandas-2.3.2━━━━━━━━━━━━━╺━━━━ 31/35 [pandas]
#   Attempting uninstall: matplotlib━━━━━━━━━━━━━━━━━━━━━━╺━━━━ 31/35 [pandas]
#     Found existing installation: matplotlib 3.10.6━━╺━━━━ 31/35 [pandas]
#     Uninstalling matplotlib-3.10.6:━━━━━━━━━━━━━━━━━╺━━━━ 31/35 [pandas]
#       Successfully uninstalled matplotlib-3.10.6━━━━━━━━━╸━━━ 32/35 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35/35 [mne-features]m━━ 33/35 [mne]lotlib]
# Successfully installed MarkupSafe-3.0.2 PyWavelets-1.8.0 certifi-2025.8.3 charset_normalizer-3.4.3 contourpy-1.3.2 cycler-0.12.1 decorator-5.2.1 fonttools-4.59.2 idna-3.10 jinja2-3.1.6 joblib-1.5.2 kiwisolver-1.4.9 lazy-loader-0.4 llvmlite-0.44.0 matplotlib-3.10.6 mne-1.10.1 mne-features-0.3 numba-0.61.2 numpy-2.2.6 packaging-25.0 pandas-2.3.2 pillow-11.3.0 platformdirs-4.4.0 pooch-1.8.2 pyparsing-3.2.4 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.5 scikit-learn-1.7.2 scipy-1.15.3 six-1.17.0 threadpoolctl-3.6.0 tqdm-4.67.1 tzdata-2025.2 urllib3-2.5.0

# %%
import mne_features
import sklearn
print(mne_features.__version__)
print(sklearn.__version__)
# Out:
# 0.3
# 1.7.2

# %%
import numpy as np
rng = np.random.RandomState(42)
n_epochs, n_channels, n_times = 5, 3, 32
X = rng.randn(n_epochs, n_channels, n_times)
fe = FeatureExtractor(sfreq=100., selected_funcs=['std', 'kurtosis'])
X = fe.fit_transform(X)
print(X.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 6
#       4 X = rng.randn(n_epochs, n_channels, n_times)
#       5 fe = FeatureExtractor(sfreq=100., selected_funcs=['std', 'kurtosis'])
# ----> 6 X = fe.fit_transform(X)
#       7 print(X.shape)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
#     881                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#     889             UserWarning,
#     890         )
#     892 if y is None:
#     893     # fit method of arity 1 (unsupervised transformation)
# --> 894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
#     897     return self.fit(X, y, **fit_params).transform(X)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:390, in FeatureExtractor.transform(self, X)
#     388 mem = joblib.Memory(location=self.memory)
#     389 _extractor = mem.cache(extract_features)
# --> 390 return _extractor(X, self.sfreq, self.selected_funcs,
#     391                   funcs_params=self.params, n_jobs=self.n_jobs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:471, in extract_features(X, sfreq, selected_funcs, funcs_params, n_jobs, ch_names, return_as_df)
#     469 if funcs_params is not None:
#     470     extractor.set_params(**funcs_params)
# --> 471 res = joblib.Parallel(n_jobs=n_jobs)(joblib.delayed(_apply_extractor)(
#     472     extractor, X[j, :, :], ch_names, return_as_df) for j in range(n_epochs)
#     473 )
#     474 feature_names = res[0][1]
#     475 res = list(zip(*res))[0]
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:223, in _apply_extractor(extractor, X, ch_names, return_as_df)
#     202 def _apply_extractor(extractor, X, ch_names, return_as_df):
#     203     """Utility function to apply features extractor to ndarray X.
#     204
#     205     Parameters
#    (...)
#     221         Not None, only if ``return_as_df`` is True.
#     222     """
# --> 223     X = extractor.fit_transform(X)
#     224     feature_names = None
#     225     if return_as_df:
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/pipeline.py:1971, in FeatureUnion.fit_transform(self, X, y, **params)
#    1968 Xs, transformers = zip(*results)
#    1969 self._update_transformer_list(transformers)
# -> 1971 return self._hstack(Xs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/pipeline.py:2044, in FeatureUnion._hstack(self, Xs)
#    2042 for X, (name, _) in zip(Xs, self.transformer_list):
#    2043     if hasattr(X, "shape") and len(X.shape) != 2:
# -> 2044         raise ValueError(
#    2045             f"Transformer '{name}' returned an array or dataframe with "
#    2046             f"{len(X.shape)} dimensions, but expected 2 dimensions "
#    2047             "(n_samples, n_features)."
#    2048         )
#    2050 adapter = _get_container_adapter("transform", self)
#    2051 if adapter and all(adapter.is_supported_container(X) for X in Xs):
#
# ValueError: Transformer 'std' returned an array or dataframe with 1 dimensions, but expected 2 dimensions (n_samples, n_features).

# %%
import numpy as np
from mne_features.feature_extraction import FeatureExtractor

freq_bands = np.array([[0.5, 4], [4, 8], [8, 13], [13, 50]])  # delta, theta, alpha, beta+gamma

params = {
    "pow_freq_bands__freq_bands": freq_bands,
    "energy_freq_bands__freq_bands": freq_bands,
}

fe = FeatureExtractor(
    sfreq=256.0,
    selected_funcs=['pow_freq_bands', 'energy_freq_bands', 'kurtosis'],
    params=params
)

features_before = fe.fit_transform(X_before)
features_after = fe.fit_transform(X_after)

print(features_before.shape)
print(features_after.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 17
#       6 params = {
#       7     "pow_freq_bands__freq_bands": freq_bands,
#       8     "energy_freq_bands__freq_bands": freq_bands,
#       9 }
#      11 fe = FeatureExtractor(
#      12     sfreq=256.0,
#      13     selected_funcs=['pow_freq_bands', 'energy_freq_bands', 'kurtosis'],
#      14     params=params
#      15 )
# ---> 17 features_before = fe.fit_transform(X_before)
#      18 features_after = fe.fit_transform(X_after)
#      20 print(features_before.shape)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
#     881                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#     889             UserWarning,
#     890         )
#     892 if y is None:
#     893     # fit method of arity 1 (unsupervised transformation)
# --> 894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
#     897     return self.fit(X, y, **fit_params).transform(X)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:390, in FeatureExtractor.transform(self, X)
#     388 mem = joblib.Memory(location=self.memory)
#     389 _extractor = mem.cache(extract_features)
# --> 390 return _extractor(X, self.sfreq, self.selected_funcs,
#     391                   funcs_params=self.params, n_jobs=self.n_jobs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:471, in extract_features(X, sfreq, selected_funcs, funcs_params, n_jobs, ch_names, return_as_df)
#     469 if funcs_params is not None:
#     470     extractor.set_params(**funcs_params)
# --> 471 res = joblib.Parallel(n_jobs=n_jobs)(joblib.delayed(_apply_extractor)(
#     472     extractor, X[j, :, :], ch_names, return_as_df) for j in range(n_epochs)
#     473 )
#     474 feature_names = res[0][1]
#     475 res = list(zip(*res))[0]
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:223, in _apply_extractor(extractor, X, ch_names, return_as_df)
#     202 def _apply_extractor(extractor, X, ch_names, return_as_df):
#     203     """Utility function to apply features extractor to ndarray X.
#     204
#     205     Parameters
#    (...)
#     221         Not None, only if ``return_as_df`` is True.
#     222     """
# --> 223     X = extractor.fit_transform(X)
#     224     feature_names = None
#     225     if return_as_df:
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/pipeline.py:1971, in FeatureUnion.fit_transform(self, X, y, **params)
#    1968 Xs, transformers = zip(*results)
#    1969 self._update_transformer_list(transformers)
# -> 1971 return self._hstack(Xs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/pipeline.py:2044, in FeatureUnion._hstack(self, Xs)
#    2042 for X, (name, _) in zip(Xs, self.transformer_list):
#    2043     if hasattr(X, "shape") and len(X.shape) != 2:
# -> 2044         raise ValueError(
#    2045             f"Transformer '{name}' returned an array or dataframe with "
#    2046             f"{len(X.shape)} dimensions, but expected 2 dimensions "
#    2047             "(n_samples, n_features)."
#    2048         )
#    2050 adapter = _get_container_adapter("transform", self)
#    2051 if adapter and all(adapter.is_supported_container(X) for X in Xs):
#
# ValueError: Transformer 'pow_freq_bands' returned an array or dataframe with 1 dimensions, but expected 2 dimensions (n_samples, n_features).

# %%
X_before = epochsBefore.get_data()
X_after  = epochsAfter.get_data()

print(X_before.shape)
print(X_after.shape)
# Out:
# (46, 4, 768)
# (58, 4, 768)
# (141312, 1)
# (178176, 1)

# %%
features_before = fe.fit_transform(X_before)
features_after = fe.fit_transform(X_after)
print(features_before.shape)  # (n_epochs, n_features)
print(features_after.shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 features_before = fe.fit_transform(X_before)
#       2 features_after = fe.fit_transform(X_after)
#       3 print(features_before.shape)  # (n_epochs, n_features)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/base.py:894, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     879         warnings.warn(
#     880             (
#     881                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)
#     889             UserWarning,
#     890         )
#     892 if y is None:
#     893     # fit method of arity 1 (unsupervised transformation)
# --> 894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
#     897     return self.fit(X, y, **fit_params).transform(X)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:390, in FeatureExtractor.transform(self, X)
#     388 mem = joblib.Memory(location=self.memory)
#     389 _extractor = mem.cache(extract_features)
# --> 390 return _extractor(X, self.sfreq, self.selected_funcs,
#     391                   funcs_params=self.params, n_jobs=self.n_jobs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:471, in extract_features(X, sfreq, selected_funcs, funcs_params, n_jobs, ch_names, return_as_df)
#     469 if funcs_params is not None:
#     470     extractor.set_params(**funcs_params)
# --> 471 res = joblib.Parallel(n_jobs=n_jobs)(joblib.delayed(_apply_extractor)(
#     472     extractor, X[j, :, :], ch_names, return_as_df) for j in range(n_epochs)
#     473 )
#     474 feature_names = res[0][1]
#     475 res = list(zip(*res))[0]
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/joblib/parallel.py:1911, in Parallel._get_sequential_output(self, iterable)
#    1908 yield None
#    1910 # Sequentially call the tasks and yield the results.
# -> 1911 for func, args, kwargs in iterable:
#    1912     self.n_dispatched_batches += 1
#    1913     self.n_dispatched_tasks += 1
#
# File /opt/homebrew/anaconda3/envs/muselsl/lib/python3.10/site-packages/mne_features/feature_extraction.py:472, in <genexpr>(.0)
#     469 if funcs_params is not None:
#     470     extractor.set_params(**funcs_params)
#     471 res = joblib.Parallel(n_jobs=n_jobs)(joblib.delayed(_apply_extractor)(
# --> 472     extractor, X[j, :, :], ch_names, return_as_df) for j in range(n_epochs)
#     473 )
#     474 feature_names = res[0][1]
#     475 res = list(zip(*res))[0]
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
print("Feature names:", fe.selected_funcs)
# Out:
# Feature names: ['pow_freq_bands', 'energy_freq_bands', 'kurtosis']

# %%
# Data analsyis 
feature_names = fe.selected_funcs

# %%
# 2nd attempt - trying to get teh column names

# %%
X_before = epochsBefore.get_data()  # shape: (n_epochs, n_channels, n_times)
ch_names = epochsBefore.ch_names    # e.g. ['TP9', 'AF7', 'AF8', 'TP10']

# Custom frequency bands as dict for nice labels
freq_bands = {
    'delta': [0.5, 4],
    'theta': [4, 8],
    'alpha': [8, 13],
    'beta+gamma': [13, 50]
}

# %%
selected_funcs = ['pow_freq_bands', 'energy_freq_bands', 'kurtosis']

features_before = extract_features(
    X_before,
    sfreq=epochsBefore.info['sfreq'],
    selected_funcs=selected_funcs,
    funcs_params={
        'pow_freq_bands__freq_bands': freq_bands,
        'energy_freq_bands__freq_bands': freq_bands,
    },
    ch_names=ch_names,
    return_as_df=True
)

# %%
print(features_before.columns)  # MultiIndex with (feature, band, channel)
# Optional: Flatten column names
features_before.columns = ['_'.join(map(str, col)) for col in features_before.columns]
print(features_before.columns.tolist())

# %%
# Do the same for after
X_after = epochsAfter.get_data()
features_after = extract_features(
    X_after,
    sfreq=epochsAfter.info['sfreq'],
    selected_funcs=selected_funcs,
    funcs_params={
        'pow_freq_bands__freq_bands': freq_bands,
        'energy_freq_bands__freq_bands': freq_bands,
    },
    ch_names=ch_names,
    return_as_df=True
)
features_after.columns = ['_'.join(map(str, col)) for col in features_after.columns]

# Pick your feature of interest (e.g., alpha power in AF7)
col = 'pow_freq_bands_AF7_alpha'

import matplotlib.pyplot as plt

plt.figure()
plt.boxplot([features_before[col], features_after[col]], labels=['Before', 'After'])
plt.ylabel('Alpha Power (AF7)')
plt.title('Alpha Power in AF7: Before vs After')
plt.show()

# %%
all_feature_columns = features_before.columns.tolist()

for col in all_feature_columns:
    plt.figure(figsize=(5, 3))
    plt.boxplot([features_before[col], features_after[col]], labels=['Before', 'After'])
    plt.ylabel(col)
    plt.title(f'{col}: Before vs After')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # now doing a correlation Matrix

# %%
corr_before = features_before.corr()
corr_after = features_after.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(corr_before, cmap='coolwarm', center=0, annot=False, fmt='.2f')
plt.title('Feature Correlation Matrix (Before)')
plt.tight_layout()
plt.show()

plt.figure(figsize=(12,10))
sns.heatmap(corr_after, cmap='coolwarm', center=0, annot=False, fmt='.2f')
plt.title('Feature Correlation Matrix (After)')
plt.tight_layout()
plt.show()

# %%
# subtract or plot the difference between the correlation matrices
corr_diff = corr_after - corr_before
plt.figure(figsize=(12,10))
sns.heatmap(corr_diff, cmap='bwr', center=0)
plt.title('Correlation Difference (After - Before)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Clustering

# %%
import pandas as pd
import numpy as np

# Combine features from both groups
X = pd.concat([features_before, features_after], ignore_index=True)
group_labels = np.array(['Before'] * len(features_before) + ['After'] * len(features_after))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=42)
cluster_labels = kmeans.fit_predict(X_scaled)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=42)
cluster_labels = kmeans.fit_predict(X_scaled)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Color by true group, not cluster!
colors = ['#1f77b4' if label == 'Before' else '#ff7f0e' for label in group_labels]

plt.figure(figsize=(8,6))
for group, color in zip(['Before', 'After'], ['#1f77b4', '#ff7f0e']):
    mask = group_labels == group
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1], c=color, label=group, alpha=0.7, edgecolor='k')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('Epochs Clustered by Features (Colored by Meditation State)')
plt.legend()
plt.tight_layout()

# code start to show cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='black', s=100, marker='X', label='Cluster Centers')
plt.legend()
# code end to show cluster centers

plt.show()

# %% [markdown]
# # Final ... Cohen test

# %% [markdown]
# # Final - Cohen Test

# %%
import numpy as np
import pandas as pd

def cohens_d(x, y):
    # x: before, y: after
    nx = len(x)
    ny = len(y)
    s1 = np.var(x, ddof=1)
    s2 = np.var(y, ddof=1)
    pooled_std = np.sqrt(((nx - 1)*s1 + (ny - 1)*s2) / (nx + ny - 2))
    d = (np.mean(y) - np.mean(x)) / pooled_std
    return d

# For all features:
cohen_d_results = {}
for col in features_before.columns:
    cohen_d_results[col] = cohens_d(features_before[col], features_after[col])

# Sort by magnitude (largest effect size first)
cohen_d_sorted = pd.Series(cohen_d_results).sort_values(key=np.abs, ascending=False)

print(cohen_d_sorted)

# %%
import matplotlib.pyplot as plt

top_n = 10
cohen_d_sorted[:top_n].plot(kind='barh', color='teal')
plt.axvline(0, color='k', linestyle='--')
plt.title(f'Top {top_n} Features by Effect Size (Cohen\'s d)')
plt.xlabel('Cohen\'s d')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
